# %% [markdown]
# # XGBoost
#
# We'll continue by evaluating a XGBoost model using AUC to get the best score. We'll also review the Confusion Matrix for the best model on the validation data as well as looking at the models precision and recall.

# %% [markdown]
# ---
#
# ## Imports and import Data

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    confusion_matrix,
    precision_score,
    recall_score,
    roc_auc_score,
)

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

from sklearn import tree

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import train_test_split


cv_method = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=999)

from sklearn.metrics import accuracy_score

# import packages for hyperparameters tuning
import xgboost as xgb
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %% [markdown]
# ### Import the data

# %%
df = pd.read_csv("./final_data.csv")

# %%
df.shape
# Out:
# (72063, 18)

# %%
# Some records are noy unique
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71866 entries, 0 to 72062
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   block                 71866 non-null  object
#  1   iucr                  71866 non-null  object
#  2   primary_type          71866 non-null  object
#  3   description           71866 non-null  object
#  4   location_description  71866 non-null  object
#  5   arrest                71866 non-null  bool
#  6   domestic              71866 non-null  bool
#  7   beat                  71866 non-null  int64
#  8   district              71866 non-null  int64
#  9   ward                  71866 non-null  int64
#  10  community_area        71866 non-null  int64
#  11  fbi_code              71866 non-null  object
#  12  latitude              71866 non-null  float64
#  13  longitude             71866 non-null  float64
#  14  hour                  71866 non-null  int64
#  15  day                   71866 non-null  int64
#  16  zip                   71866 non-null  object
#  17  street                71866 non-null  object
# dtypes: bool(2), float64(2), int64(6), object(8)
# memory usage: 9.5+ MB

# %% [markdown]
# ### Set Target
#
# The target feature is `arrest` which is a boolean feature. For the medel we need to change this to `0` and `1` values.
#
# We will also change the `domestic` feature in the same manner

# %%
df.arrest = df.arrest.astype(int)
df.domestic = df.domestic.astype(int)

# %% [markdown]
# ### Identify Catergorical and Numeric Columns

# %%
categorical_columns = [
    "iucr",
    "primary_type",
    "description",
    "location_description",
    "fbi_code",
    "zip",
    "street",
]

numerical_columns = [
    "domestic",
    "beat",
    "district",
    "ward",
    "community_area",
    "latitude",
    "longitude",
    "hour",
    "day",
]

features = categorical_columns + numerical_columns

# %% [markdown]
# ---
#
# # XGBoost
#
# ### Split the Data
#
# The data will be split as follows:
#
# #### Training
#
# 80% of the data will be used for Training. During training K-Fold cross validation will be used.
#
# One the best model parameters are identified the full training dataset will be used to train the final model.
#
# #### Test
#
# 20% of the data will be help back for final testing of the model.

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

dict_train = df_train[features].to_dict(orient="records")
dict_val = df_val[features].to_dict(orient="records")
dict_test = df_test[features].to_dict(orient="records")

dv = DictVectorizer(sparse=False)

X_train = dv.fit_transform(dict_train)
X_val = dv.transform(dict_val)
X_test = dv.transform(dict_test)

y_train = df_train.arrest.values
y_val = df_val.arrest.values
y_test = df_test.arrest.values

# %%
dict_train[0]
# Out:
# {'iucr': '143A',
#  'primary_type': 'WEAPONS VIOLATION',
#  'description': 'UNLAWFUL POSSESSION - HANDGUN',
#  'location_description': 'STREET',
#  'fbi_code': '15',
#  'zip': '001XX',
#  'street': 'W, HUBBARD, ST',
#  'domestic': 0,
#  'beat': 1831,
#  'district': 18,
#  'ward': 42,
#  'community_area': 8,
#  'latitude': 41.890011565,
#  'longitude': -87.631793561,
#  'hour': 21,
#  'day': 1}

# %% [markdown]
# ---
#
# ### RMSE

# %%
from hyperopt import hp
import numpy as np
from sklearn.metrics import mean_squared_error


# XGB parameters
xgb_reg_params = {
    "learning_rate": hp.choice("learning_rate", np.arange(0.05, 0.31, 0.05)),
    "max_depth": hp.choice("max_depth", np.arange(5, 16, 1, dtype=int)),
    "min_child_weight": hp.choice("min_child_weight", np.arange(1, 8, 1, dtype=int)),
    "colsample_bytree": hp.choice("colsample_bytree", np.arange(0.3, 0.8, 0.1)),
    "subsample": hp.uniform("subsample", 0.8, 1),
    "n_estimators": 100,
    "eval_metric": "rmse",
    "early_stopping_rounds": 10,
}
xgb_para = dict()
xgb_para["reg_params"] = xgb_reg_params
xgb_para["loss_func"] = lambda y, pred: np.sqrt(mean_squared_error(y, pred))

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials


class HPOpt(object):
    def __init__(self, x_train, x_test, y_train, y_test):
        self.x_train = x_train
        self.x_test = x_test
        self.y_train = y_train
        self.y_test = y_test

    def process(self, fn_name, space, trials, algo, max_evals):
        fn = getattr(self, fn_name)
        try:
            result = fmin(
                fn=fn, space=space, algo=algo, max_evals=max_evals, trials=trials
            )
        except Exception as e:
            return {"status": STATUS_FAIL, "exception": str(e)}
        return result, trials

    def xgb_reg(self, para):
        reg = xgb.XGBRegressor(**para["reg_params"])
        return self.train_reg(reg, para)

    def train_reg(self, reg, para):
        reg.fit(
            self.x_train,
            self.y_train,
            eval_set=[(self.x_train, self.y_train), (self.x_test, self.y_test)],
        )
        pred = reg.predict(self.x_test)
        loss = para["loss_func"](self.y_test, pred)
        return {"loss": loss, "status": STATUS_OK}

# %%
obj = HPOpt(X_train, X_val, y_train, y_val)

xgb_opt = obj.process(
    fn_name="xgb_reg", space=xgb_para, trials=Trials(), algo=tpe.suggest, max_evals=10
)
# Out:
# [0]	validation_0-rmse:0.41451	validation_1-rmse:0.41612
# [1]	validation_0-rmse:0.36855	validation_1-rmse:0.37202
# [2]	validation_0-rmse:0.33716	validation_1-rmse:0.34365
# [3]	validation_0-rmse:0.31730	validation_1-rmse:0.32487
# [4]	validation_0-rmse:0.30605	validation_1-rmse:0.31552
# [5]	validation_0-rmse:0.29948	validation_1-rmse:0.31004
# [6]	validation_0-rmse:0.29535	validation_1-rmse:0.30708
# [7]	validation_0-rmse:0.29312	validation_1-rmse:0.30565
# [8]	validation_0-rmse:0.29102	validation_1-rmse:0.30401
# [9]	validation_0-rmse:0.29017	validation_1-rmse:0.30348
# [10]	validation_0-rmse:0.28882	validation_1-rmse:0.30302
# [11]	validation_0-rmse:0.28708	validation_1-rmse:0.30207
# [12]	validation_0-rmse:0.28632	validation_1-rmse:0.30163
# [13]	validation_0-rmse:0.28588	validation_1-rmse:0.30136
# [14]	validation_0-rmse:0.28521	validation_1-rmse:0.30108
# [15]	validation_0-rmse:0.28492	validation_1-rmse:0.30099
# [16]	validation_0-rmse:0.28420	validation_1-rmse:0.30091
# [17]	validation_0-rmse:0.28392	validation_1-rmse:0.30075
# [18]	validation_0-rmse:0.28362	validation_1-rmse:0.30069
# [19]	validation_0-rmse:0.28326	validation_1-rmse:0.30064
# [20]	validation_0-rmse:0.28279	validation_1-rmse:0.30061
# [21]	validation_0-rmse:0.28152	validation_1-rmse:0.30047
# [22]	validation_0-rmse:0.28091	validation_1-rmse:0.30045
# [23]	validation_0-rmse:0.28034	validation_1-rmse:0.30041
# [24]	validation_0-rmse:0.28010	validation_1-rmse:0.30031
# [25]	validation_0-rmse:0.27945	validation_1-rmse:0.30038
# [26]	validation_0-rmse:0.27919	validation_1-rmse:0.30039
# [27]	validation_0-rmse:0.27893	validation_1-rmse:0.30041
# [28]	validation_0-rmse:0.27876	validation_1-rmse:0.30050
# [29]	validation_0-rmse:0.27834	validation_1-rmse:0.30056
# [30]	validation_0-rmse:0.27815	validation_1-rmse:0.30054
# [31]	validation_0-rmse:0.27784	validation_1-rmse:0.30053
# [32]	validation_0-rmse:0.27771	validation_1-rmse:0.30046
# [33]	validation_0-rmse:0.27741	validation_1-rmse:0.30051
# [34]	validation_0-rmse:0.27720	validation_1-rmse:0.30049
# [0]	validation_0-rmse:0.42695	validation_1-rmse:0.42855
# [1]	validation_0-rmse:0.37763	validation_1-rmse:0.38069
# [2]	validation_0-rmse:0.34689	validation_1-rmse:0.35145
# [3]	validation_0-rmse:0.32727	validation_1-rmse:0.33313
# [4]	validation_0-rmse:0.31411	validation_1-rmse:0.32112
# [5]	validation_0-rmse:0.30702	validation_1-rmse:0.31489
# [6]	validation_0-rmse:0.30231	validation_1-rmse:0.31073
# [7]	validation_0-rmse:0.29907	validation_1-rmse:0.30808
# [8]	validation_0-rmse:0.29702	validation_1-rmse:0.30662
# [9]	validation_0-rmse:0.29494	validation_1-rmse:0.30506
# [10]	validation_0-rmse:0.29360	validation_1-rmse:0.30449
# [11]	validation_0-rmse:0.29277	validation_1-rmse:0.30379
# [12]	validation_0-rmse:0.29215	validation_1-rmse:0.30337
# [13]	validation_0-rmse:0.29132	validation_1-rmse:0.30294
# [14]	validation_0-rmse:0.29071	validation_1-rmse:0.30251
# [15]	validation_0-rmse:0.28980	validation_1-rmse:0.30226
# [16]	validation_0-rmse:0.28911	validation_1-rmse:0.30194
# [17]	validation_0-rmse:0.28864	validation_1-rmse:0.30171
# [18]	validation_0-rmse:0.28821	validation_1-rmse:0.30142
# [19]	validation_0-rmse:0.28783	validation_1-rmse:0.30124
# [20]	validation_0-rmse:0.28738	validation_1-rmse:0.30110
# [21]	validation_0-rmse:0.28697	validation_1-rmse:0.30084
# [22]	validation_0-rmse:0.28671	validation_1-rmse:0.30094
# [23]	validation_0-rmse:0.28644	validation_1-rmse:0.30087
# [24]	validation_0-rmse:0.28610	validation_1-rmse:0.30077
# [25]	validation_0-rmse:0.28540	validation_1-rmse:0.30067
# [26]	validation_0-rmse:0.28503	validation_1-rmse:0.30061
# [27]	validation_0-rmse:0.28452	validation_1-rmse:0.30066
# [28]	validation_0-rmse:0.28423	validation_1-rmse:0.30078
# [29]	validation_0-rmse:0.28405	validation_1-rmse:0.30085
# [30]	validation_0-rmse:0.28323	validation_1-rmse:0.30062
# [31]	validation_0-rmse:0.28248	validation_1-rmse:0.30043
# [32]	validation_0-rmse:0.28184	validation_1-rmse:0.30032
# [33]	validation_0-rmse:0.28173	validation_1-rmse:0.30027
# [34]	validation_0-rmse:0.28140	validation_1-rmse:0.30034
# [35]	validation_0-rmse:0.28123	validation_1-rmse:0.30024
# [36]	validation_0-rmse:0.28091	validation_1-rmse:0.30031
# [37]	validation_0-rmse:0.28050	validation_1-rmse:0.30048
# [38]	validation_0-rmse:0.27992	validation_1-rmse:0.30043
# [39]	validation_0-rmse:0.27983	validation_1-rmse:0.30046
# [40]	validation_0-rmse:0.27946	validation_1-rmse:0.30037
# [41]	validation_0-rmse:0.27906	validation_1-rmse:0.30043
# [42]	validation_0-rmse:0.27888	validation_1-rmse:0.30036
# [43]	validation_0-rmse:0.27872	validation_1-rmse:0.30027
# [44]	validation_0-rmse:0.27834	validation_1-rmse:0.30022
# [45]	validation_0-rmse:0.27789	validation_1-rmse:0.30021
# [46]	validation_0-rmse:0.27781	validation_1-rmse:0.30028
# [47]	validation_0-rmse:0.27762	validation_1-rmse:0.30033
# [48]	validation_0-rmse:0.27721	validation_1-rmse:0.30034
# [49]	validation_0-rmse:0.27703	validation_1-rmse:0.30032
# [50]	validation_0-rmse:0.27687	validation_1-rmse:0.30038
# [51]	validation_0-rmse:0.27677	validation_1-rmse:0.30038
# [52]	validation_0-rmse:0.27664	validation_1-rmse:0.30039
# [53]	validation_0-rmse:0.27653	validation_1-rmse:0.30041
# [54]	validation_0-rmse:0.27605	validation_1-rmse:0.30054
# [0]	validation_0-rmse:0.48822	validation_1-rmse:0.48841
# [1]	validation_0-rmse:0.47605	validation_1-rmse:0.47650
# [2]	validation_0-rmse:0.46359	validation_1-rmse:0.46441
# [3]	validation_0-rmse:0.45095	validation_1-rmse:0.45196
# [4]	validation_0-rmse:0.44188	validation_1-rmse:0.44318
# [5]	validation_0-rmse:0.43063	validation_1-rmse:0.43217
# [6]	validation_0-rmse:0.42214	validation_1-rmse:0.42393
# [7]	validation_0-rmse:0.41360	validation_1-rmse:0.41574
# [8]	validation_0-rmse:0.40454	validation_1-rmse:0.40688
# [9]	validation_0-rmse:0.39724	validation_1-rmse:0.39989
# [10]	validation_0-rmse:0.39141	validation_1-rmse:0.39430
# [11]	validation_0-rmse:0.38472	validation_1-rmse:0.38772
# [12]	validation_0-rmse:0.37938	validation_1-rmse:0.38275
# [94]	validation_0-rmse:0.29550	validation_1-rmse:0.30446
# [95]	validation_0-rmse:0.29543	validation_1-rmse:0.30438
# [96]	validation_0-rmse:0.29535	validation_1-rmse:0.30430
# [97]	validation_0-rmse:0.29526	validation_1-rmse:0.30426
# [98]	validation_0-rmse:0.29518	validation_1-rmse:0.30419
# [99]	validation_0-rmse:0.29507	validation_1-rmse:0.30412
# [0]	validation_0-rmse:0.41376	validation_1-rmse:0.41557
# [1]	validation_0-rmse:0.36663	validation_1-rmse:0.37038
# [2]	validation_0-rmse:0.33486	validation_1-rmse:0.34236
# [3]	validation_0-rmse:0.31542	validation_1-rmse:0.32413
# [4]	validation_0-rmse:0.30389	validation_1-rmse:0.31523
# [5]	validation_0-rmse:0.29729	validation_1-rmse:0.30968
# [6]	validation_0-rmse:0.29201	validation_1-rmse:0.30624
# [7]	validation_0-rmse:0.28975	validation_1-rmse:0.30509
# [8]	validation_0-rmse:0.28706	validation_1-rmse:0.30319
# [9]	validation_0-rmse:0.28641	validation_1-rmse:0.30282
# [10]	validation_0-rmse:0.28494	validation_1-rmse:0.30244
# [11]	validation_0-rmse:0.28385	validation_1-rmse:0.30187
# [12]	validation_0-rmse:0.28276	validation_1-rmse:0.30163
# [13]	validation_0-rmse:0.28175	validation_1-rmse:0.30146
# [14]	validation_0-rmse:0.28073	validation_1-rmse:0.30117
# [15]	validation_0-rmse:0.28054	validation_1-rmse:0.30117
# [16]	validation_0-rmse:0.27966	validation_1-rmse:0.30124
# [17]	validation_0-rmse:0.27941	validation_1-rmse:0.30122
# [18]	validation_0-rmse:0.27900	validation_1-rmse:0.30128
# [19]	validation_0-rmse:0.27864	validation_1-rmse:0.30123
# [20]	validation_0-rmse:0.27806	validation_1-rmse:0.30131
# [21]	validation_0-rmse:0.27670	validation_1-rmse:0.30131
# [22]	validation_0-rmse:0.27639	validation_1-rmse:0.30139
# [23]	validation_0-rmse:0.27583	validation_1-rmse:0.30137
# [24]	validation_0-rmse:0.27554	validation_1-rmse:0.30142
# [0]	validation_0-rmse:0.44177	validation_1-rmse:0.44273
# [1]	validation_0-rmse:0.40359	validation_1-rmse:0.40555
# [2]	validation_0-rmse:0.37303	validation_1-rmse:0.37692
# [3]	validation_0-rmse:0.34941	validation_1-rmse:0.35403
# [4]	validation_0-rmse:0.33405	validation_1-rmse:0.34003
# [5]	validation_0-rmse:0.32206	validation_1-rmse:0.32877
# [6]	validation_0-rmse:0.31488	validation_1-rmse:0.32227
# [7]	validation_0-rmse:0.30960	validation_1-rmse:0.31774
# [8]	validation_0-rmse:0.30485	validation_1-rmse:0.31356
# [9]	validation_0-rmse:0.30175	validation_1-rmse:0.31117
# [10]	validation_0-rmse:0.29931	validation_1-rmse:0.30915
# [11]	validation_0-rmse:0.29708	validation_1-rmse:0.30706
# [12]	validation_0-rmse:0.29540	validation_1-rmse:0.30574
# [13]	validation_0-rmse:0.29404	validation_1-rmse:0.30461
# [43]	validation_0-rmse:0.31015	validation_1-rmse:0.31619
# [44]	validation_0-rmse:0.30960	validation_1-rmse:0.31568
# [45]	validation_0-rmse:0.30895	validation_1-rmse:0.31509
# [46]	validation_0-rmse:0.30834	validation_1-rmse:0.31457
# [47]	validation_0-rmse:0.30776	validation_1-rmse:0.31405
# [48]	validation_0-rmse:0.30739	validation_1-rmse:0.31375
# [49]	validation_0-rmse:0.30679	validation_1-rmse:0.31320
# [50]	validation_0-rmse:0.30642	validation_1-rmse:0.31288
# [51]	validation_0-rmse:0.30589	validation_1-rmse:0.31240
# [52]	validation_0-rmse:0.30549	validation_1-rmse:0.31200
# [53]	validation_0-rmse:0.30508	validation_1-rmse:0.31165
# [54]	validation_0-rmse:0.30473	validation_1-rmse:0.31134
# [55]	validation_0-rmse:0.30437	validation_1-rmse:0.31105
# [56]	validation_0-rmse:0.30402	validation_1-rmse:0.31072
# [57]	validation_0-rmse:0.30380	validation_1-rmse:0.31053
# [58]	validation_0-rmse:0.30350	validation_1-rmse:0.31027
# [59]	validation_0-rmse:0.30313	validation_1-rmse:0.30994
# [60]	validation_0-rmse:0.30285	validation_1-rmse:0.30967
# [61]	validation_0-rmse:0.30249	validation_1-rmse:0.30931
# [62]	validation_0-rmse:0.30218	validation_1-rmse:0.30906
# [63]	validation_0-rmse:0.30192	validation_1-rmse:0.30887
# [64]	validation_0-rmse:0.30165	validation_1-rmse:0.30862
# [65]	validation_0-rmse:0.30147	validation_1-rmse:0.30849
# [66]	validation_0-rmse:0.30118	validation_1-rmse:0.30824
# [67]	validation_0-rmse:0.30098	validation_1-rmse:0.30806
# [68]	validation_0-rmse:0.30073	validation_1-rmse:0.30784
# [69]	validation_0-rmse:0.30053	validation_1-rmse:0.30766
# [70]	validation_0-rmse:0.30031	validation_1-rmse:0.30749
# [71]	validation_0-rmse:0.30013	validation_1-rmse:0.30732
# [72]	validation_0-rmse:0.29995	validation_1-rmse:0.30717
# [73]	validation_0-rmse:0.29976	validation_1-rmse:0.30702
# [74]	validation_0-rmse:0.29961	validation_1-rmse:0.30690
# [75]	validation_0-rmse:0.29950	validation_1-rmse:0.30682
# [76]	validation_0-rmse:0.29930	validation_1-rmse:0.30665
# [77]	validation_0-rmse:0.29917	validation_1-rmse:0.30654
# [78]	validation_0-rmse:0.29897	validation_1-rmse:0.30638
# [79]	validation_0-rmse:0.29879	validation_1-rmse:0.30625
# [80]	validation_0-rmse:0.29866	validation_1-rmse:0.30614
# [81]	validation_0-rmse:0.29854	validation_1-rmse:0.30605
# [82]	validation_0-rmse:0.29840	validation_1-rmse:0.30593
# [83]	validation_0-rmse:0.29830	validation_1-rmse:0.30581
# [84]	validation_0-rmse:0.29816	validation_1-rmse:0.30573
# [85]	validation_0-rmse:0.29805	validation_1-rmse:0.30564
# [86]	validation_0-rmse:0.29784	validation_1-rmse:0.30548
# [87]	validation_0-rmse:0.29772	validation_1-rmse:0.30536
# [88]	validation_0-rmse:0.29762	validation_1-rmse:0.30527
# [89]	validation_0-rmse:0.29753	validation_1-rmse:0.30519
# [90]	validation_0-rmse:0.29743	validation_1-rmse:0.30512
# [91]	validation_0-rmse:0.29732	validation_1-rmse:0.30504
# [92]	validation_0-rmse:0.29722	validation_1-rmse:0.30495
# [93]	validation_0-rmse:0.29713	validation_1-rmse:0.30486
# [94]	validation_0-rmse:0.29705	validation_1-rmse:0.30479
# [95]	validation_0-rmse:0.29696	validation_1-rmse:0.30473
# [96]	validation_0-rmse:0.29688	validation_1-rmse:0.30466
# [97]	validation_0-rmse:0.29681	validation_1-rmse:0.30461
# [98]	validation_0-rmse:0.29673	validation_1-rmse:0.30454
# [99]	validation_0-rmse:0.29662	validation_1-rmse:0.30446
# [0]	validation_0-rmse:0.45487	validation_1-rmse:0.45594
# [1]	validation_0-rmse:0.42062	validation_1-rmse:0.42287
# [2]	validation_0-rmse:0.39038	validation_1-rmse:0.39415
# [3]	validation_0-rmse:0.36641	validation_1-rmse:0.37125
# [4]	validation_0-rmse:0.34606	validation_1-rmse:0.35320
# [5]	validation_0-rmse:0.33187	validation_1-rmse:0.34025
# [6]	validation_0-rmse:0.32222	validation_1-rmse:0.33175
# [7]	validation_0-rmse:0.31313	validation_1-rmse:0.32394
# [8]	validation_0-rmse:0.30651	validation_1-rmse:0.31812
# [9]	validation_0-rmse:0.30105	validation_1-rmse:0.31353
# [10]	validation_0-rmse:0.29704	validation_1-rmse:0.31038
# [11]	validation_0-rmse:0.29334	validation_1-rmse:0.30755
# [12]	validation_0-rmse:0.29081	validation_1-rmse:0.30553
# [13]	validation_0-rmse:0.28890	validation_1-rmse:0.30415
# [14]	validation_0-rmse:0.28733	validation_1-rmse:0.30313
# [15]	validation_0-rmse:0.28551	validation_1-rmse:0.30203
# [16]	validation_0-rmse:0.28442	validation_1-rmse:0.30155
# [17]	validation_0-rmse:0.28377	validation_1-rmse:0.30115
# [18]	validation_0-rmse:0.28321	validation_1-rmse:0.30078
# [19]	validation_0-rmse:0.28248	validation_1-rmse:0.30055
# [20]	validation_0-rmse:0.28134	validation_1-rmse:0.30037
# [21]	validation_0-rmse:0.28061	validation_1-rmse:0.30023
# [22]	validation_0-rmse:0.28023	validation_1-rmse:0.30015
# [23]	validation_0-rmse:0.27953	validation_1-rmse:0.29998
# [24]	validation_0-rmse:0.27907	validation_1-rmse:0.29990
# [25]	validation_0-rmse:0.27831	validation_1-rmse:0.29981
# [26]	validation_0-rmse:0.27803	validation_1-rmse:0.29975
# [27]	validation_0-rmse:0.27723	validation_1-rmse:0.29975
# [28]	validation_0-rmse:0.27692	validation_1-rmse:0.29973
# [29]	validation_0-rmse:0.27640	validation_1-rmse:0.29979
# [30]	validation_0-rmse:0.27582	validation_1-rmse:0.29980
# [31]	validation_0-rmse:0.27536	validation_1-rmse:0.29980
# [32]	validation_0-rmse:0.27520	validation_1-rmse:0.29974
# [33]	validation_0-rmse:0.27491	validation_1-rmse:0.29967
# [34]	validation_0-rmse:0.27461	validation_1-rmse:0.29963
# [35]	validation_0-rmse:0.27428	validation_1-rmse:0.29962
# [36]	validation_0-rmse:0.27402	validation_1-rmse:0.29964
# [37]	validation_0-rmse:0.27370	validation_1-rmse:0.29970
# [38]	validation_0-rmse:0.27342	validation_1-rmse:0.29977
# [39]	validation_0-rmse:0.27324	validation_1-rmse:0.29980
# [40]	validation_0-rmse:0.27280	validation_1-rmse:0.29982
# [41]	validation_0-rmse:0.27253	validation_1-rmse:0.29984
# [42]	validation_0-rmse:0.27240	validation_1-rmse:0.29981
# [43]	validation_0-rmse:0.27222	validation_1-rmse:0.29981
# [44]	validation_0-rmse:0.27185	validation_1-rmse:0.29986
# [0]	validation_0-rmse:0.45416	validation_1-rmse:0.45508
# [1]	validation_0-rmse:0.41411	validation_1-rmse:0.41622
# [2]	validation_0-rmse:0.38072	validation_1-rmse:0.38479
# [3]	validation_0-rmse:0.35433	validation_1-rmse:0.35922
# [4]	validation_0-rmse:0.33890	validation_1-rmse:0.34561
# [5]	validation_0-rmse:0.32452	validation_1-rmse:0.33211
# [6]	validation_0-rmse:0.31681	validation_1-rmse:0.32509
# [7]	validation_0-rmse:0.31068	validation_1-rmse:0.31991
# [8]	validation_0-rmse:0.30483	validation_1-rmse:0.31453
# [9]	validation_0-rmse:0.30149	validation_1-rmse:0.31200
# [10]	validation_0-rmse:0.29901	validation_1-rmse:0.31002
# [11]	validation_0-rmse:0.29626	validation_1-rmse:0.30747
# [12]	validation_0-rmse:0.29434	validation_1-rmse:0.30630
# [13]	validation_0-rmse:0.29267	validation_1-rmse:0.30480
# [14]	validation_0-rmse:0.29127	validation_1-rmse:0.30373
# [15]	validation_0-rmse:0.29033	validation_1-rmse:0.30311
# [16]	validation_0-rmse:0.28936	validation_1-rmse:0.30268
# [17]	validation_0-rmse:0.28883	validation_1-rmse:0.30217
# [18]	validation_0-rmse:0.28816	validation_1-rmse:0.30174
# [19]	validation_0-rmse:0.28744	validation_1-rmse:0.30140
# [20]	validation_0-rmse:0.28676	validation_1-rmse:0.30121
# [21]	validation_0-rmse:0.28622	validation_1-rmse:0.30096
# [22]	validation_0-rmse:0.28560	validation_1-rmse:0.30070
# [23]	validation_0-rmse:0.28533	validation_1-rmse:0.30058
# [24]	validation_0-rmse:0.28510	validation_1-rmse:0.30040
# [25]	validation_0-rmse:0.28452	validation_1-rmse:0.30027
# [26]	validation_0-rmse:0.28424	validation_1-rmse:0.30014
# [27]	validation_0-rmse:0.28381	validation_1-rmse:0.30025
# [28]	validation_0-rmse:0.28352	validation_1-rmse:0.30015
# [29]	validation_0-rmse:0.28307	validation_1-rmse:0.30015
# [30]	validation_0-rmse:0.28271	validation_1-rmse:0.30010
# [31]	validation_0-rmse:0.28243	validation_1-rmse:0.30008
# [32]	validation_0-rmse:0.28228	validation_1-rmse:0.30007
# [33]	validation_0-rmse:0.28178	validation_1-rmse:0.29997
# [34]	validation_0-rmse:0.28144	validation_1-rmse:0.29996
# [35]	validation_0-rmse:0.28123	validation_1-rmse:0.29986
# [36]	validation_0-rmse:0.28087	validation_1-rmse:0.29988
# [37]	validation_0-rmse:0.28058	validation_1-rmse:0.29990
# [38]	validation_0-rmse:0.28025	validation_1-rmse:0.29972
# [39]	validation_0-rmse:0.28006	validation_1-rmse:0.29971
# [40]	validation_0-rmse:0.27983	validation_1-rmse:0.29972
# [41]	validation_0-rmse:0.27949	validation_1-rmse:0.29967
# [42]	validation_0-rmse:0.27935	validation_1-rmse:0.29967
# [43]	validation_0-rmse:0.27910	validation_1-rmse:0.29966
# [44]	validation_0-rmse:0.27877	validation_1-rmse:0.29964
# [45]	validation_0-rmse:0.27848	validation_1-rmse:0.29966
# [46]	validation_0-rmse:0.27820	validation_1-rmse:0.29974
# [47]	validation_0-rmse:0.27788	validation_1-rmse:0.29970
# [48]	validation_0-rmse:0.27755	validation_1-rmse:0.29963
# [49]	validation_0-rmse:0.27748	validation_1-rmse:0.29964
# [50]	validation_0-rmse:0.27718	validation_1-rmse:0.29962
# [51]	validation_0-rmse:0.27624	validation_1-rmse:0.29957
# [52]	validation_0-rmse:0.27616	validation_1-rmse:0.29955
# [53]	validation_0-rmse:0.27600	validation_1-rmse:0.29958
# [54]	validation_0-rmse:0.27585	validation_1-rmse:0.29963
# [55]	validation_0-rmse:0.27567	validation_1-rmse:0.29966
# [56]	validation_0-rmse:0.27542	validation_1-rmse:0.29971
# [57]	validation_0-rmse:0.27533	validation_1-rmse:0.29968
# [58]	validation_0-rmse:0.27519	validation_1-rmse:0.29969
# [59]	validation_0-rmse:0.27511	validation_1-rmse:0.29969
# [60]	validation_0-rmse:0.27496	validation_1-rmse:0.29962
# [61]	validation_0-rmse:0.27488	validation_1-rmse:0.29961
# [0]	validation_0-rmse:0.44194	validation_1-rmse:0.44290
# [1]	validation_0-rmse:0.40421	validation_1-rmse:0.40610
# [2]	validation_0-rmse:0.37424	validation_1-rmse:0.37795
# [3]	validation_0-rmse:0.35089	validation_1-rmse:0.35525
# [4]	validation_0-rmse:0.33624	validation_1-rmse:0.34169
# [5]	validation_0-rmse:0.32443	validation_1-rmse:0.33044
# [6]	validation_0-rmse:0.31724	validation_1-rmse:0.32382
# [7]	validation_0-rmse:0.31196	validation_1-rmse:0.31912
# [8]	validation_0-rmse:0.30717	validation_1-rmse:0.31498
# [9]	validation_0-rmse:0.30449	validation_1-rmse:0.31279
# [10]	validation_0-rmse:0.30213	validation_1-rmse:0.31084
# [11]	validation_0-rmse:0.29990	validation_1-rmse:0.30876
# [12]	validation_0-rmse:0.29827	validation_1-rmse:0.30739
# [13]	validation_0-rmse:0.29696	validation_1-rmse:0.30615
# [14]	validation_0-rmse:0.29576	validation_1-rmse:0.30516
# [15]	validation_0-rmse:0.29510	validation_1-rmse:0.30462
# [16]	validation_0-rmse:0.29431	validation_1-rmse:0.30416
# [17]	validation_0-rmse:0.29378	validation_1-rmse:0.30376
# [18]	validation_0-rmse:0.29321	validation_1-rmse:0.30336
# [19]	validation_0-rmse:0.29257	validation_1-rmse:0.30293
# [20]	validation_0-rmse:0.29212	validation_1-rmse:0.30269
# [21]	validation_0-rmse:0.29161	validation_1-rmse:0.30237
# [22]	validation_0-rmse:0.29130	validation_1-rmse:0.30218
# [23]	validation_0-rmse:0.29095	validation_1-rmse:0.30203
# [24]	validation_0-rmse:0.29063	validation_1-rmse:0.30189
# [25]	validation_0-rmse:0.29032	validation_1-rmse:0.30176
# [26]	validation_0-rmse:0.29013	validation_1-rmse:0.30169
# [27]	validation_0-rmse:0.28963	validation_1-rmse:0.30158
# [28]	validation_0-rmse:0.28931	validation_1-rmse:0.30145
# [29]	validation_0-rmse:0.28905	validation_1-rmse:0.30131
# [30]	validation_0-rmse:0.28860	validation_1-rmse:0.30117
# [31]	validation_0-rmse:0.28829	validation_1-rmse:0.30104
# [32]	validation_0-rmse:0.28788	validation_1-rmse:0.30105
# [33]	validation_0-rmse:0.28773	validation_1-rmse:0.30093
# [34]	validation_0-rmse:0.28745	validation_1-rmse:0.30091
# [35]	validation_0-rmse:0.28733	validation_1-rmse:0.30083
# [36]	validation_0-rmse:0.28704	validation_1-rmse:0.30073
# [37]	validation_0-rmse:0.28654	validation_1-rmse:0.30056
# [38]	validation_0-rmse:0.28635	validation_1-rmse:0.30055
# [39]	validation_0-rmse:0.28607	validation_1-rmse:0.30053
# [40]	validation_0-rmse:0.28581	validation_1-rmse:0.30054
# [41]	validation_0-rmse:0.28569	validation_1-rmse:0.30058
# [42]	validation_0-rmse:0.28553	validation_1-rmse:0.30038
# [43]	validation_0-rmse:0.28539	validation_1-rmse:0.30037
# [44]	validation_0-rmse:0.28514	validation_1-rmse:0.30026
# [45]	validation_0-rmse:0.28498	validation_1-rmse:0.30029
# [46]	validation_0-rmse:0.28484	validation_1-rmse:0.30030
# [47]	validation_0-rmse:0.28441	validation_1-rmse:0.30029
# [48]	validation_0-rmse:0.28403	validation_1-rmse:0.30015
# [49]	validation_0-rmse:0.28391	validation_1-rmse:0.30015
# [50]	validation_0-rmse:0.28379	validation_1-rmse:0.30016
# [51]	validation_0-rmse:0.28310	validation_1-rmse:0.30004
# [52]	validation_0-rmse:0.28302	validation_1-rmse:0.29996
# [53]	validation_0-rmse:0.28286	validation_1-rmse:0.29994
# [54]	validation_0-rmse:0.28256	validation_1-rmse:0.29986
# [55]	validation_0-rmse:0.28235	validation_1-rmse:0.29987
# [56]	validation_0-rmse:0.28208	validation_1-rmse:0.29988
# [57]	validation_0-rmse:0.28200	validation_1-rmse:0.29985
# [58]	validation_0-rmse:0.28183	validation_1-rmse:0.29981
# [59]	validation_0-rmse:0.28174	validation_1-rmse:0.29980
# [60]	validation_0-rmse:0.28164	validation_1-rmse:0.29978
# [61]	validation_0-rmse:0.28152	validation_1-rmse:0.29971
# [62]	validation_0-rmse:0.28143	validation_1-rmse:0.29973
# [63]	validation_0-rmse:0.28131	validation_1-rmse:0.29972
# [64]	validation_0-rmse:0.28121	validation_1-rmse:0.29962
# [65]	validation_0-rmse:0.28079	validation_1-rmse:0.29960
# [66]	validation_0-rmse:0.28065	validation_1-rmse:0.29957
# [67]	validation_0-rmse:0.28040	validation_1-rmse:0.29953
# [68]	validation_0-rmse:0.28019	validation_1-rmse:0.29954
# [69]	validation_0-rmse:0.27995	validation_1-rmse:0.29952
# [70]	validation_0-rmse:0.27989	validation_1-rmse:0.29950
# [71]	validation_0-rmse:0.27979	validation_1-rmse:0.29951
# [72]	validation_0-rmse:0.27975	validation_1-rmse:0.29952
# [73]	validation_0-rmse:0.27966	validation_1-rmse:0.29955
# [74]	validation_0-rmse:0.27948	validation_1-rmse:0.29957
# [75]	validation_0-rmse:0.27938	validation_1-rmse:0.29957
# [76]	validation_0-rmse:0.27928	validation_1-rmse:0.29956
# [77]	validation_0-rmse:0.27910	validation_1-rmse:0.29964
# [78]	validation_0-rmse:0.27879	validation_1-rmse:0.29968
# [79]	validation_0-rmse:0.27865	validation_1-rmse:0.29973
# [80]	validation_0-rmse:0.27859	validation_1-rmse:0.29973
# 100%|██████████| 10/10 [03:17<00:00, 19.72s/trial, best loss: 0.2993208914002846]

# %%
# Best parameters
xgb_opt
# Out:
# ({'colsample_bytree': 1,
#   'learning_rate': 3,
#   'max_depth': 3,
#   'min_child_weight': 5,
#   'subsample': 0.8899372509684718},
#  <hyperopt.base.Trials at 0x2904f2da0>)

# %%
learning_rate = np.arange(0.05, 0.31, 0.05)
max_depth = np.arange(5, 16, 1, dtype=int)
min_child_weight = np.arange(1, 8, 1, dtype=int)
colsample_bytree = np.arange(0.3, 0.8, 0.1)

# %%
cs = colsample_bytree[1]
lr = learning_rate[3]
md = max_depth[3]
mcw = min_child_weight[5]

# %%
print(f"colsample_bytree: {cs}")
print(f"learning_rate: {lr}")
print(f"max_depth: {md}")
print(f"min_child_weight: {mcw}")
print(f"subsample: 0.8899372509684718")
# Out:
# colsample_bytree: 0.4
# learning_rate: 0.2
# max_depth: 8
# min_child_weight: 6
# subsample: 0.8899372509684718

# %%
xg = xgb.XGBClassifier(
    colsample_bytree=cs,
    learning_rate=lr,
    max_depth=md,
    min_child_weight=mcw,
    subsample=0.900961518576018,
    eval_metric="rmse",
    early_stopping_rounds=10,
)

evaluation = [(X_train, y_train), (X_val, y_val)]

xg.fit(
    X_train,
    y_train,
    eval_set=evaluation,
    verbose=False,
)

y_pred = xg.predict(X_test)

# %%
print("Confusion Matrix Tree : \n", confusion_matrix(y_test, y_pred), "\n")
print("The precision for Tree is ", precision_score(y_test, y_pred))
print("The recall for Tree is ", recall_score(y_test, y_pred), "\n")
# Out:
# Confusion Matrix Tree :
#  [[11113   172]
#  [ 1355  1734]]
#
# The precision for Tree is  0.9097586568730325
# The recall for Tree is  0.5613467141469731
